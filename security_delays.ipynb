# %%
# Add the pandas dependency.

import pandas as pd

# %%
# Files to load

security_data_to_load = "Resources/claims-2014.csv"

# %%
# Read the school data file and store it in a Pandas DataFrame.

security_df = pd.read_csv(security_data_to_load)

security_df
# Out:
#       Claim Number Date Received Incident Date Airport Code  \
# 0     2.013082e+12     13-Jan-14     21-Dec-12          HPN
# 1     2.014080e+12     17-Jul-14     30-Jun-14          MCO
# 2     2.014011e+12      7-Jan-14     27-Dec-13          SJU
# 3     2.014011e+12      7-Jan-14      2-Jan-14          IAD
# 4     2.014011e+12      9-Jan-14      7-Jan-14          SAT
# ...            ...           ...           ...          ...
# 9409           NaN           NaN           NaN          NaN
# 9410           NaN           NaN           NaN          NaN
# 9411           NaN           NaN           NaN          NaN
# 9412           NaN           NaN           NaN          NaN
# 9413           NaN           NaN           NaN          NaN
#
#                           Airport Name          Airline Name       Claim Type  \
# 0     Westchester County, White Plains               USAir    Personal Injury
# 1        Orlando International Airport     Delta Air Lines    Property Damage
# ...
