# %%
# Random Forest Feature Selection
# Initial imports
import pandas as pd
from path import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Read in CSV file.
# df = pd.read_csv("loans_data_encoded.csv")
# df = pd.read_csv("security_data.csv")
# df = pd.read_csv("AA_Airline_Delay_Cause.csv")
df = pd.read_csv("All_Airline_Delay_Cause_2022.csv")
# df = pd.read_csv("AviationData_Weather.csv") ??FILE WONT LOAD
# df = pd.read_csv("Airline_Delay_Cause_2020.csv")
# df = pd.read_csv("Delay_Causes_2015-2022.csv")
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022     10      9E  Endeavor Air Inc.     ATL
# 1  2022     10      9E  Endeavor Air Inc.     BNA
# 2  2022     10      9E  Endeavor Air Inc.     BOS
# 3  2022     10      9E  Endeavor Air Inc.     BWI
# 4  2022     10      9E  Endeavor Air Inc.     CLT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       1172.0      115.0
# 1             Nashville, TN: Nashville International        238.0       40.0
# 2                    Boston, MA: Logan International         71.0       11.0
# 3  Baltimore, MD: Baltimore/Washington Internatio...         93.0       15.0
# 4     Charlotte, NC: Charlotte Douglas International        280.0       40.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       34.04        6.44  ...          0.0             48.26            0.0
# ...

# %%
# df is AA data for 9 months of 2022.
#weather_delay	nas_delay	security_delay, late_aircraft_delay

# %%
# df2 = df[['arr_flights', 'carrier_delay']].copy()
df2 = df[['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']].copy()
df2 = df2.dropna()
df2.head()
# Out:
#    carrier_delay  weather_delay  nas_delay  security_delay  \
# 0         5378.0          714.0      958.0             0.0
# 1          641.0          108.0      442.0             0.0
# 2         1095.0          303.0      224.0             0.0
# 3           70.0            0.0      248.0             0.0
# 4         1009.0           10.0      656.0             0.0
#
#    late_aircraft_delay
# 0               3476.0
# 1               1156.0
# 2                208.0
# 3                757.0
# 4               1332.0

# %%
print(df.shape)
# Out:
# (3386, 21)

# %%
# X is the input data (independent variable) and y is the output data (target variable).
X = df2.copy()
X.head()
# Out:
#    carrier_delay  weather_delay  nas_delay  security_delay
# 0         5378.0          714.0      958.0             0.0
# 1          641.0          108.0      442.0             0.0
# 2         1095.0          303.0      224.0             0.0
# 3           70.0            0.0      248.0             0.0
# 4         1009.0           10.0      656.0             0.0

# %%
# y = X.pop('late_aircraft_delay')
# Define the target vector
y= df2["late_aircraft_delay"].values.reshape(-1, 1)
y[:5]
# Out:
# array([[3476.],
#        [1156.],
#        [ 208.],
#        [ 757.],
#        [1332.]])

# %%
# print(X.shape)
# print(X.shape)
# Out:
# (3386, 4)

# %%
# Split into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2539, 4)
# (847, 4)
# (2539, 1)
# (847, 1)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, random_state=78, train_size=0.80)

# %%
print(X_train2.shape)
print(X_test2.shape)
print(y_train2.shape)
print(y_test2.shape)
# Out:
# (2708, 4)
# (678, 4)
# (2708, 1)
# (678, 1)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Creating the decision tree classifier instance
model = tree.DecisionTreeClassifier()

# %%
# Fitting the model
model = model.fit(X_train_scaled, y_train)

# %%
# Make predictions using the Tree Model

# %%
# Making predictions using the testing data
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([3.41000e+02, 1.50000e+01, 1.19870e+04, 4.06000e+02, 6.01800e+03,
#        2.24000e+02, 2.02000e+03, 6.64000e+02, 1.10000e+02, 0.00000e+00,
#        8.59400e+03, 0.00000e+00, 4.78400e+03, 7.87000e+02, 7.58800e+03,
#        1.70000e+01, 6.44500e+03, 1.83750e+04, 3.19900e+03, 2.30000e+01,
#        7.52000e+02, 5.30200e+03, 1.60960e+04, 1.99320e+04, 3.97000e+02,
#        5.60000e+02, 7.58000e+02, 5.57900e+03, 2.35000e+02, 1.35650e+04,
#        1.00170e+04, 7.85300e+03, 1.40000e+01, 1.33000e+02, 1.69700e+03,
#        7.38000e+02, 2.12000e+03, 4.12300e+03, 3.70000e+01, 6.66100e+04,
#        1.44200e+04, 1.40000e+02, 4.95000e+02, 8.59000e+03, 1.71000e+02,
#        1.39500e+03, 2.07500e+03, 3.40500e+03, 4.22800e+03, 2.83000e+02,
#        1.18130e+04, 4.58000e+02, 4.43800e+03, 1.06000e+03, 1.54000e+02,
#        1.50000e+01, 5.15400e+03, 2.99400e+03, 3.47670e+04, 1.71000e+02,
#        3.95500e+03, 5.28680e+04, 4.11500e+03, 1.06580e+04, 2.85500e+03,
# ...

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
#     cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
# Empty DataFrame
# Columns: []
# Index: []
# Accuracy Score : 0.03541912632821724
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.48      0.48        63
#          2.0       0.00      0.00      0.00         1
#          3.0       0.00      0.00      0.00         1
#          6.0       0.00      0.00      0.00         0
#          8.0       0.00      0.00      0.00         1
#          9.0       0.00      0.00      0.00         2
#         10.0       0.00      0.00      0.00         1
#         11.0       0.00      0.00      0.00         1
#         12.0       0.00      0.00      0.00         1
#         13.0       0.00      0.00      0.00         1
#         14.0       0.00      0.00      0.00         1
#         15.0       0.00      0.00      0.00         1
#         16.0       0.00      0.00      0.00         1
#         17.0       0.00      0.00      0.00         1
# ...

# %%
# Create StandardScaler instance, fit scaler and scale data.
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Fit the Decision Tree Model

# Creating the decision tree classifier instance
model = tree.DecisionTreeClassifier()

# %%
# Fitting the model
model = model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = model.predict(X_test_scaled)

# %%
# predictions

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
# acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))

# %%
X

# %%
y

# %%
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

# %%
features = clf.feature_importances_
print(features)
plt.bar(x = range(len(features)), height=features)
plt.show()

# %%
# Select features based on importance weights
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel
sel = SelectFromModel(clf)
sel.fit(X_train_scaled, y_train)

# Get a mask (integer index of the features selected)
sel.get_support()

# %%
# Show selected features
sel.get_feature_names_out()

# %%
# Get train, test data, reduce data into selected features
X_selected_train, X_selected_test, y_train, y_test = train_test_split(sel.transform(X), y, random_state=1)

# Standarize data
scaler = StandardScaler().fit(X_selected_train)
X_selected_train_scaled = scaler.transform(X_selected_train)
X_selected_test_scaled = scaler.transform(X_selected_test)

# %%
# Train with original data

# %%
clf = LogisticRegression().fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

# %%
clf = LogisticRegression()
clf.fit(X_selected_train_scaled, y_train)
print(f'Training Score: {clf.score(X_selected_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_selected_test_scaled, y_test)}')

# %%
# df2 = df[['arr_flights', 'carrier_delay']].copy()
df2 = df[['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']].copy()
df2 = df2.dropna()
df2.head()

# %%
# # Create data
# X, y = make_classification(random_state=42, n_features=10, n_informative=5, n_redundant=0, n_samples=1000)
# # Create data frame with features
# X = pd.DataFrame(X)
# Split into train/text
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(df.shape)
df.columns

# %%
# Create a Decision Tree Classifier
clf = DecisionTreeClassifier().fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)
cm

# %%
X_test

# %%
cm_df = df.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df

# %%
print(classification_report(y_test, y_pred))

# %%
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

# %%
# df2 = df[['arr_flights', 'carrier_delay']].copy()
df2 = df[['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']].copy()
df2 = df2.dropna()
df2.head()

# %%
print(df2.shape)
df2.columns

# %%
import graphviz

# %%
# Create a decision tree graph
import graphviz 
dot_data = tree.export_graphviz(
    clf, out_file=None, 
    feature_names=data.feature_names,  
    class_names=data.target_names,  
    filled=True, rounded=True,  
    special_characters=True)  

import pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('iris.png')

graph = graphviz.Source(dot_data)  
graph

# %%
# Plotting in Pairplot of Titanic Data
import seaborn as sns

data = pd.read_csv("AA_Airline_Delay_Cause.csv", 
                usecols=['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay'])

sns.pairplot(data=data, hue='carrier_delay', kind='hist')
plt.show()

# %%
# Plotting in Pairplot of Titanic Data
import seaborn as sns

# data = pd.read_csv("AA_Airline_Delay_Cause.csv", 
#                 usecols=['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay'])
df2 = data
sns.pairplot(data=data, hue='late_aircraft_delay')
plt.show()

# %%
# Plotting in Pairplot of Titanic Data
import seaborn as sns

df = data
sns.pairplot(
    data,
    x_vars=['weather_delay', 'nas_delay', 'security_delay'],
    y_vars=['weather_delay', 'nas_delay'],)
# plt.show()

# %%
X = data.copy()
y = X.pop('late_aircraft_delay')

# %%
X

# %%
y

# %%
# Splitting data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)

# %%
# Create a decision tree classifier
clf = DecisionTreeClassifier()

# Train
# clf.fit(df.data, df.target)
clf.fit(X_train, y_train)

# Get accuracy of the model
# clf.score(data.data, data.target)

# %%
X_train

# %%
y_train

# %%
# Make predictions with the model
predictions = clf.predict(X_test)
print(predictions[:5])

# %%
# Measuring the accuracy of our model
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, predictions))

# %%
df2 = df[['carrier', 'arr_flights', 'carrier_delay']].copy()

df2.head()

# %%
print(df2.shape)
df2.columns

# %%
delay = df2['arr_flights'].sum()
delay

# %%
delay = df2['carrier_delay'].sum()
delay

# %%
plt.scatter(df2.arr_flights, df.carrier_delay)
plt.xlabel('arriving flights')
plt.ylabel('carrier delays')
plt.show()

# %%
X = df2.arr_flights.values.reshape(-1, 1)

# %%
df2

# %%
X[:5]

# %%
X.shape

# %% [markdown]
# ### Using a dataset with an incorrect shape, or formatting, can cause errors in Scikit-learn. Remember that you may have to use reshape() to format your data properly.

# %%
# does y need reshape?
y = df2.carrier_delay

# %%
# create an instance of the linear regression model. Instantiate the model.
model = LinearRegression()
model

# %%
# Drop Nans
# df2 = df2.dropna(how='all')
# df2

# df2 = df2.dropna(subset=df2.columns.values)

# %%
# df3 = df2[df2['carrier'] != 'Nan'].copy()
# print(df3.shape)
# df3.head()

# %%
# DF Types
print(df2.dtypes)
print(df2.count)

# %%
# Learning stage 
model.fit(X, y)

# %%
# Use predict method to generate predictions.
y_pred = model.predict(X)
print(y_pred.shape)

# %%
# Plot the best fit line.
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
# Examine specific parameters of the model. 
# Slope is represented by model.coef_ and model.intercept_ (y-intercept)
print(model.coef_)
print(model.intercept_)

# %% [markdown]
# ### previous ml attempt on security_data.csv ###

# %%
# df2 = df[df['Disposition'] != '-'].copy()
# print(df2.shape)
# df2.head()

# %%
df2.dtypes

# %%
df2['Date Received'] =  pd.to_datetime(df2['Date Received'], format='%d-%b-%y')
df2['Incident Date'] =  pd.to_datetime(df2['Incident Date'], format='%d-%b-%y')

# %%
print(df2.shape)
df2.head()

# %%
df2.columns

# %%
df3 =df2[['Date Received', 'Incident Date', 'Airport Code', 'Airline Name', 'Claim Type', 'Claim Site',
       'Item Category', 'Close Amount']].copy()

df3.head()

# %%
df3['Claim Type'].value_counts()

# %%
keep_claim_type = ['Passenger Property Loss', 'Property Damage']
df3 = df3[df3['Claim Type'].isin(keep_claim_type)].copy()
print(df3.shape)
df3.head()

# %%
df3['Claim Site'].value_counts()

# %%
keep_claim_site = ['Checked Baggage', 'Checkpoint']
df3 = df3[df3['Claim Site'].isin(keep_claim_site)].copy()
print(df3.shape)
df3.head()

# %%
df3['diff_days'] = (df3['Date Received'] - df3['Incident Date']) / np.timedelta64(1, 'D')
df3.head()

# %%
Airline = df3['Airline Name'].value_counts()
Airline[Airline>5]

# %%
airline_types_to_replace = list(Airline[Airline < 60].index)

for air in airline_types_to_replace:
    df3['Airline Name'] = df3['Airline Name'].replace(air,"Other")

df3['Airline Name'].value_counts()

# %%
df3['Airline Name'] = df3['Airline Name'].replace('-',"Other")
df3['Airline Name'].value_counts()

# %%
Airport = df3['Airport Code'].value_counts()
Airport[Airport>50]

# %%
airport_types_to_replace = list(Airport[Airport < 50].index)

for air in airport_types_to_replace:
    df3['Airport Code'] = df3['Airport Code'].replace(air,"Other")

df3['Airport Code'].value_counts()

# %%
Items = df3['Item Category'].value_counts()
Items[Items>50]

# %%
items_types_to_replace = list(Items[Items < 50].index)

for item in items_types_to_replace:
    df3['Item Category'] = df3['Item Category'].replace(item,"Other")

df3['Item Category'].value_counts()

# %%
df3['Item Category'] = df3['Item Category'].replace('-',"Other")
df3['Item Category'].value_counts()

# %%
df3['Close Amount'] = df3['Close Amount'].str.replace('$',"")
df3['Close Amount'] = df3['Close Amount'].str.replace(',',"")

# %%
df3.dtypes

# %%
df3['Close Amount'] = df3['Close Amount'].astype(str).astype(float)
df3.dtypes

# %%
df3.head()

# %%
df3.columns

# %%
df4 = df3[['Airport Code', 'Airline Name',
       'Claim Type', 'Claim Site', 'Item Category', 'Close Amount',
       'diff_days']].copy()
df4.head()

# %%
df_get_dummies = pd.get_dummies(df4)
df_get_dummies.head()

# %%
# Convert categorical data into dummy indicator variables.
df_get_dummies.to_csv("df_get_dummies.csv")

# %%
X = df_get_dummies.drop('Close Amount', axis = 1).values

y = df_get_dummies['Close Amount'].values

# %%
X

# %%
y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
X_train[:5]

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# 17.7.3

# %%
# knn = KNeighborsRegressor(n_neighbors=1)
# knn.fit(X_train,y_train)

# %%
new = preprocessing.LabelEncoder()
y_transformed = new.fit_transform(y)

print(y_transformed)

# %%
# fit logistic regression model
model = LogisticRegression()
model.fit(X, y_transformed)

# %%
# Creating the decision tree classifier instance.
# model = tree.DecisionTreeClassifier()
# # Fitting the model.
# model = model.fit(X_train, y_train)

# %%
# Making predictions using the testing data.
predictions = model.predict(X_test_scaled)
predictions

# %%
predictions

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)

# # Create a DataFrame from the confustion matrix.
# cm_df = pdf.DataFrame(
# cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])
# cm_df

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)
acc_score

# %%
(True Positives (TP) + True Negatives (TN)) / Total = (50 + 19)/125 = 0.552

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
